# %% [markdown]
# # Academic Performance Analyzer - EDA

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

df = pd.read_csv('student_dataset_cleaned.csv')
df.head()
# Out:
#    Unnamed: 0.1  Unnamed: 0 code_module code_presentation  id_student gender  \
# 0             0           0         AAA             2013J       11391      M
# 1             1           1         AAA             2013J       11391      M
# 2             2           2         AAA             2013J       11391      M
# 3             3           3         AAA             2013J       11391      M
# 4             4           4         AAA             2013J       11391      M
#
#                 region highest_education imd_band age_band  ...  \
# 0  East Anglian Region  HE Qualification  90-100%     55<=  ...
# 1  East Anglian Region  HE Qualification  90-100%     55<=  ...
# 2  East Anglian Region  HE Qualification  90-100%     55<=  ...
# 3  East Anglian Region  HE Qualification  90-100%     55<=  ...
# 4  East Anglian Region  HE Qualification  90-100%     55<=  ...
#
#    date_unregistration  module_presentation_length id_assessment  \
# ...

# %%
df.shape
# Out:
# (180662, 25)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 180662 entries, 0 to 180661
# Data columns (total 25 columns):
#  #   Column                      Non-Null Count   Dtype
# ---  ------                      --------------   -----
#  0   Unnamed: 0.1                180662 non-null  int64
#  1   Unnamed: 0                  180662 non-null  int64
#  2   code_module                 180662 non-null  object
#  3   code_presentation           180662 non-null  object
#  4   id_student                  180662 non-null  int64
#  5   gender                      180662 non-null  object
#  6   region                      180662 non-null  object
#  7   highest_education           180662 non-null  object
#  8   imd_band                    180662 non-null  object
#  9   age_band                    180662 non-null  object
#  10  num_of_prev_attempts        180662 non-null  int64
#  11  studied_credits             180662 non-null  int64
#  12  disability                  180662 non-null  object
# ...

# %%
df.describe()
# Out:
#         Unnamed: 0.1     Unnamed: 0    id_student  num_of_prev_attempts  \
# count  180662.000000  180662.000000  1.806620e+05         180662.000000
# mean    90330.500000   90330.500000  7.049706e+05              0.146539
# std     52152.771504   52152.771504  5.515387e+05              0.448563
# min         0.000000       0.000000  3.733000e+03              0.000000
# 25%     45165.250000   45165.250000  5.051990e+05              0.000000
# 50%     90330.500000   90330.500000  5.855030e+05              0.000000
# 75%    135495.750000  135495.750000  6.346460e+05              0.000000
# max    180661.000000  180661.000000  2.716795e+06              6.000000
#
#        studied_credits  module_presentation_length  id_assessment  \
# count    180662.000000               180662.000000  180662.000000
# mean         77.317726                  255.245530   26469.408808
# std          37.924814                   13.569578    8673.846088
# ...

# %%
df.isnull().sum()
# Out:
# Unnamed: 0.1                  0
# Unnamed: 0                    0
# code_module                   0
# code_presentation             0
# id_student                    0
# gender                        0
# region                        0
# highest_education             0
# imd_band                      0
# age_band                      0
# num_of_prev_attempts          0
# studied_credits               0
# disability                    0
# final_result                  0
# date_registration             0
# date_unregistration           0
# module_presentation_length    0
# id_assessment                 0
# date_submitted                0
# is_banked                     0
# score                         0
# assessment_type               0
# date                          0
# weight                        0
# sum_click                     0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
plt.figure()
plt.hist(df['Unnamed: 0.1'], bins=20)
plt.title('Unnamed: 0.1 Distribution')
plt.show()

# %%
plt.figure()
plt.hist(df['Unnamed: 0'], bins=20)
plt.title('Unnamed: 0 Distribution')
plt.show()

# %%
plt.figure()
plt.hist(df['id_student'], bins=20)
plt.title('id_student Distribution')
plt.show()

# %%
plt.figure()
plt.hist(df['num_of_prev_attempts'], bins=20)
plt.title('num_of_prev_attempts Distribution')
plt.show()

# %%
plt.figure()
plt.hist(df['studied_credits'], bins=20)
plt.title('studied_credits Distribution')
plt.show()

# %%
plt.figure()
plt.hist(df['module_presentation_length'], bins=20)
plt.title('module_presentation_length Distribution')
plt.show()

# %%
plt.figure()
plt.hist(df['id_assessment'], bins=20)
plt.title('id_assessment Distribution')
plt.show()

# %%
plt.figure()
plt.hist(df['date_submitted'], bins=20)
plt.title('date_submitted Distribution')
plt.show()

# %%
plt.figure()
plt.hist(df['is_banked'], bins=20)
plt.title('is_banked Distribution')
plt.show()

# %%
plt.figure()
plt.hist(df['score'], bins=20)
plt.title('score Distribution')
plt.show()

# %%
plt.figure()
plt.hist(df['date'], bins=20)
plt.title('date Distribution')
plt.show()

# %%
plt.figure()
plt.hist(df['weight'], bins=20)
plt.title('weight Distribution')
plt.show()

# %%
plt.figure()
plt.hist(df['sum_click'], bins=20)
plt.title('sum_click Distribution')
plt.show()

# %%
plt.figure(figsize=(10,6))
sns.heatmap(df.corr(numeric_only=True), annot=True)
plt.show()

# %%
df.columns.tolist()
# Out:
# ['Unnamed: 0.1',
#  'Unnamed: 0',
#  'code_module',
#  'code_presentation',
#  'id_student',
#  'gender',
#  'region',
#  'highest_education',
#  'imd_band',
#  'age_band',
#  'num_of_prev_attempts',
#  'studied_credits',
#  'disability',
#  'final_result',
#  'date_registration',
#  'date_unregistration',
#  'module_presentation_length',
#  'id_assessment',
#  'date_submitted',
#  'is_banked',
#  'score',
#  'assessment_type',
#  'date',
#  'weight',
#  'sum_click']
